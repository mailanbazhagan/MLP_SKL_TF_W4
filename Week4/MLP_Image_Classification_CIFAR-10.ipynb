# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical

# %%
# Function to load and preprocess the CIFAR-10 data
def load_and_preprocess_data():
    # Load CIFAR-10 dataset
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
    
    # Normalize pixel values to the range [0, 1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0
    
    # Flatten the images to 1D arrays (32x32x3 -> 3072)
    x_train = x_train.reshape(-1, 32*32*3)
    x_test = x_test.reshape(-1, 32*32*3)
    
    # One-hot encode the labels
    y_train = to_categorical(y_train, 10)
    y_test = to_categorical(y_test, 10)
    
    return (x_train, y_train), (x_test, y_test)

# Function to create the MLP model
def create_model():
    model = models.Sequential([
        layers.Dense(512, activation='relu', input_shape=(3072,)),
        layers.Dropout(0.2),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(10, activation='softmax')  # Output layer for 10 classes
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# Load and preprocess CIFAR-10 data
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()

# Create the model
model = create_model()

# Plot the model architecture
tf.keras.utils.plot_model(model,
                          to_file="model_cifar10.png",
                          show_shapes=True,
                          show_layer_names=True,
                          rankdir="TB",
                          expand_nested=False,
                          dpi=96)

# Display the model plot
from IPython.display import Image
Image('model_cifar10.png')

# Train the model
history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=20,
                    validation_split=0.2,
                    verbose=1)

# Evaluate the model on the test data
loss, accuracy = model.evaluate(x_test, y_test)

print(f"Model Accuracy: {accuracy * 100:.2f}%")
print(f"Model Loss: {loss:.4f}")

# Generate predictions
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Generate classification report
print("\nClassification Report:")
print(classification_report(y_test_classes, y_pred_classes, target_names=[str(i) for i in range(10)]))

# Confusion Matrix
cm = confusion_matrix(y_test_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[str(i) for i in range(10)])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# Plot Loss Curve
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Plot Accuracy Curve
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Curve")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce so we will re-download the data.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 367s 2us/step
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# C:\Users\shanmuka\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.1911 - loss: 2.2018 - val_accuracy: 0.3383 - val_loss: 1.8565
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3098 - loss: 1.8877 - val_accuracy: 0.3530 - val_loss: 1.7907
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.3425 - loss: 1.8169 - val_accuracy: 0.3647 - val_loss: 1.7510
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.3553 - loss: 1.7780 - val_accuracy: 0.3956 - val_loss: 1.6852
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3762 - loss: 1.7389 - val_accuracy: 0.4031 - val_loss: 1.6691
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.3741 - loss: 1.7341 - val_accuracy: 0.4002 - val_loss: 1.6713
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.3838 - loss: 1.7043 - val_accuracy: 0.4200 - val_loss: 1.6269
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.3968 - loss: 1.6742 - val_accuracy: 0.4193 - val_loss: 1.6207
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3959 - loss: 1.6740 - val_accuracy: 0.4239 - val_loss: 1.6156
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4033 - loss: 1.6536 - val_accuracy: 0.4214 - val_loss: 1.6098
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4012 - loss: 1.6384 - val_accuracy: 0.4182 - val_loss: 1.6054
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4053 - loss: 1.6349 - val_accuracy: 0.4363 - val_loss: 1.5881
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4134 - loss: 1.6238 - val_accuracy: 0.4313 - val_loss: 1.5950
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4177 - loss: 1.6117 - val_accuracy: 0.4482 - val_loss: 1.5582
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4255 - loss: 1.6027 - val_accuracy: 0.4529 - val_loss: 1.5579
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4197 - loss: 1.6062 - val_accuracy: 0.4493 - val_loss: 1.5516
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4340 - loss: 1.5671 - val_accuracy: 0.4367 - val_loss: 1.5818
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4327 - loss: 1.5700 - val_accuracy: 0.4430 - val_loss: 1.5797
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4325 - loss: 1.5742 - val_accuracy: 0.4591 - val_loss: 1.5337
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4374 - loss: 1.5530 - val_accuracy: 0.4465 - val_loss: 1.5586
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4500 - loss: 1.5330
# Model Accuracy: 44.89%
# Model Loss: 1.5412
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.45      0.50      1000
#            1       0.66      0.45      0.54      1000
#            2       0.35      0.28      0.31      1000
#            3       0.29      0.26      0.27      1000
#            4       0.35      0.46      0.40      1000
#            5       0.45      0.28      0.34      1000
#            6       0.41      0.62      0.49      1000
#            7       0.56      0.42      0.48      1000
#            8       0.49      0.70      0.58      1000
#            9       0.47      0.56      0.51      1000
#
#     accuracy                           0.45     10000
#    macro avg       0.46      0.45      0.44     10000
# weighted avg       0.46      0.45      0.44     10000
