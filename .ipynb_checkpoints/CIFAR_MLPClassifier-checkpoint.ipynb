# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
(X_train,Y_train), (X_test,Y_test) = cifar10.load_data()
X_train = X_train.astype('float32')/255.0
X_test = X_test.astype('float32')/255.0
Y_train = to_categorical(Y_train, 10)
Y_test = to_categorical(Y_test, 10)

# %%
X_train = X_train.reshape(-1, 32*32*3)
X_test = X_test.reshape(-1, 32*32*3)

# %%
model = Sequential([
    Dense(512, activation='relu', input_shape=(3072,)),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, Y_train, epochs=20, batch_size=64,validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.2086 - loss: 2.1512 - val_accuracy: 0.3435 - val_loss: 1.8096
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.3134 - loss: 1.8748 - val_accuracy: 0.3544 - val_loss: 1.7682
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.3287 - loss: 1.8319 - val_accuracy: 0.3816 - val_loss: 1.7167
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3535 - loss: 1.7888 - val_accuracy: 0.4030 - val_loss: 1.6800
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3546 - loss: 1.7765 - val_accuracy: 0.4085 - val_loss: 1.6936
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3658 - loss: 1.7501 - val_accuracy: 0.3984 - val_loss: 1.6973
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3712 - loss: 1.7285 - val_accuracy: 0.3930 - val_loss: 1.6847
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.3779 - loss: 1.7194 - val_accuracy: 0.4078 - val_loss: 1.6544
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3779 - loss: 1.7097 - val_accuracy: 0.4250 - val_loss: 1.6571
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3840 - loss: 1.7010 - val_accuracy: 0.4152 - val_loss: 1.6355
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.3912 - loss: 1.6795 - val_accuracy: 0.4395 - val_loss: 1.5998
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.3952 - loss: 1.6748 - val_accuracy: 0.4325 - val_loss: 1.5999
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.3973 - loss: 1.6639 - val_accuracy: 0.4399 - val_loss: 1.5955
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 16ms/step - accuracy: 0.3999 - loss: 1.6613 - val_accuracy: 0.4456 - val_loss: 1.5755
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4099 - loss: 1.6420 - val_accuracy: 0.4407 - val_loss: 1.5856
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.4052 - loss: 1.6356 - val_accuracy: 0.4412 - val_loss: 1.5698
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.4054 - loss: 1.6498 - val_accuracy: 0.4409 - val_loss: 1.5689
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.4183 - loss: 1.6184 - val_accuracy: 0.4407 - val_loss: 1.5628
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.4132 - loss: 1.6196 - val_accuracy: 0.4566 - val_loss: 1.5385
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.4179 - loss: 1.6173 - val_accuracy: 0.4434 - val_loss: 1.5641

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test Accuracy: ", test_acc)
print("Test Loss: ", test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4465 - loss: 1.5556
# Test Accuracy:  0.44339999556541443
# Test Loss:  1.5640898942947388

# %%
Y_pred = np.argmax(model.predict(X_test), axis=1)
Y_true = np.argmax(Y_test, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print(classification_report(Y_true, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.39      0.47      1000
#            1       0.65      0.47      0.54      1000
#            2       0.36      0.14      0.20      1000
#            3       0.30      0.24      0.27      1000
#            4       0.36      0.43      0.39      1000
#            5       0.44      0.32      0.37      1000
#            6       0.35      0.70      0.46      1000
#            7       0.51      0.51      0.51      1000
#            8       0.48      0.73      0.58      1000
#            9       0.52      0.53      0.52      1000
#
#     accuracy                           0.44     10000
#    macro avg       0.46      0.44      0.43     10000
# weighted avg       0.46      0.44      0.43     10000

# %%
CM = confusion_matrix(Y_true, Y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=CM)
disp.plot(cmap='Blues')

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
