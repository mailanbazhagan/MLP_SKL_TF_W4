# %%
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape(-1, 28*28).astype("float32")
x_test = x_test.reshape(-1, 28*28).astype("float32")

scaler = MinMaxScaler(feature_range=(0, 1))
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)


y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
model = tf.keras.Sequential([
 tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)),
 tf.keras.layers.Dropout(0.2),
 tf.keras.layers.Dense(256, activation='relu'),
 tf.keras.layers.Dropout(0.2),
 tf.keras.layers.Dense(128, activation='relu'),
 tf.keras.layers.Dropout(0.2),
 tf.keras.layers.Dense(10, activation='softmax')
 ])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
 loss='categorical_crossentropy',
 metrics=['accuracy'])

# %%
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(model,to_file="model.png",show_shapes=True,show_layer_names=True,rankdir="TB",expand_nested=False,dpi=96, )
from IPython.display import Image
Image('model.png')

# %%
history = model.fit(x_train, y_train,
 batch_size=128,
 epochs=20,
 validation_split=0.2,
 verbose=1)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8044 - loss: 0.6267 - val_accuracy: 0.9584 - val_loss: 0.1377
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9573 - loss: 0.1398 - val_accuracy: 0.9698 - val_loss: 0.1007
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9706 - loss: 0.0957 - val_accuracy: 0.9711 - val_loss: 0.1007
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9754 - loss: 0.0784 - val_accuracy: 0.9730 - val_loss: 0.0997
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9824 - loss: 0.0580 - val_accuracy: 0.9738 - val_loss: 0.0899
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9823 - loss: 0.0546 - val_accuracy: 0.9774 - val_loss: 0.0827
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9864 - loss: 0.0417 - val_accuracy: 0.9745 - val_loss: 0.0976
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9868 - loss: 0.0406 - val_accuracy: 0.9799 - val_loss: 0.0816
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9885 - loss: 0.0326 - val_accuracy: 0.9798 - val_loss: 0.0815
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9886 - loss: 0.0362 - val_accuracy: 0.9787 - val_loss: 0.0902
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9902 - loss: 0.0294 - val_accuracy: 0.9781 - val_loss: 0.0871
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9911 - loss: 0.0274 - val_accuracy: 0.9793 - val_loss: 0.0870
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9925 - loss: 0.0225 - val_accuracy: 0.9802 - val_loss: 0.0826
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9929 - loss: 0.0221 - val_accuracy: 0.9795 - val_loss: 0.0861
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9925 - loss: 0.0239 - val_accuracy: 0.9796 - val_loss: 0.0866
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9938 - loss: 0.0205 - val_accuracy: 0.9801 - val_loss: 0.0852
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9937 - loss: 0.0181 - val_accuracy: 0.9802 - val_loss: 0.0944
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9935 - loss: 0.0203 - val_accuracy: 0.9806 - val_loss: 0.0924
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9935 - loss: 0.0197 - val_accuracy: 0.9802 - val_loss: 0.0873
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9940 - loss: 0.0174 - val_accuracy: 0.9813 - val_loss: 0.0959

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from IPython.display import Image


(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()


x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


x_train = x_train.reshape(-1, 32 * 32 * 3)
x_test = x_test.reshape(-1, 32 * 32 * 3)

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)


model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(32 * 32 * 3,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


plot_model(model, to_file="model.png", show_shapes=True, show_layer_names=True,
           rankdir="TB", expand_nested=False, dpi=96)




history = model.fit(
    x_train, y_train,
    batch_size=128,
    epochs=20,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 33s 97ms/step - accuracy: 0.1621 - loss: 2.2378 - val_accuracy: 0.3241 - val_loss: 1.8724
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 32s 103ms/step - accuracy: 0.3040 - loss: 1.9087 - val_accuracy: 0.3613 - val_loss: 1.7729
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - accuracy: 0.3337 - loss: 1.8286 - val_accuracy: 0.3618 - val_loss: 1.7893
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.3531 - loss: 1.7800 - val_accuracy: 0.3791 - val_loss: 1.7308
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 103ms/step - accuracy: 0.3716 - loss: 1.7531 - val_accuracy: 0.4057 - val_loss: 1.6858
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 102ms/step - accuracy: 0.3821 - loss: 1.7231 - val_accuracy: 0.4237 - val_loss: 1.6472
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 93ms/step - accuracy: 0.3914 - loss: 1.6966 - val_accuracy: 0.4195 - val_loss: 1.6329
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.3950 - loss: 1.6819 - val_accuracy: 0.4108 - val_loss: 1.6408
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.3999 - loss: 1.6630 - val_accuracy: 0.4316 - val_loss: 1.6040
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 92ms/step - accuracy: 0.4129 - loss: 1.6373 - val_accuracy: 0.4280 - val_loss: 1.5928
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 98ms/step - accuracy: 0.4227 - loss: 1.6112 - val_accuracy: 0.4338 - val_loss: 1.5953
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.4205 - loss: 1.6139 - val_accuracy: 0.4410 - val_loss: 1.5831
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.4224 - loss: 1.5934 - val_accuracy: 0.4396 - val_loss: 1.5612
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 29s 93ms/step - accuracy: 0.4282 - loss: 1.5898 - val_accuracy: 0.4369 - val_loss: 1.5837
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 93ms/step - accuracy: 0.4372 - loss: 1.5763 - val_accuracy: 0.4350 - val_loss: 1.5777
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.4298 - loss: 1.5760 - val_accuracy: 0.4580 - val_loss: 1.5172
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.4326 - loss: 1.5790 - val_accuracy: 0.4491 - val_loss: 1.5389
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 93ms/step - accuracy: 0.4411 - loss: 1.5511 - val_accuracy: 0.4569 - val_loss: 1.5420
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 93ms/step - accuracy: 0.4453 - loss: 1.5331 - val_accuracy: 0.4566 - val_loss: 1.5420
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 98ms/step - accuracy: 0.4552 - loss: 1.5290 - val_accuracy: 0.4582 - val_loss: 1.5339

# %%
model = tf.keras.Sequential([
 tf.keras.layers.Dense(512, activation='relu', input_shape=(1024,)),
 tf.keras.layers.Dropout(0.2),
 tf.keras.layers.Dense(256, activation='relu'),
 tf.keras.layers.Dropout(0.2),
 tf.keras.layers.Dense(128, activation='relu'),
 tf.keras.layers.Dropout(0.2),
 tf.keras.layers.Dense(10, activation='softmax')
 ])
model.compile(optimizer='adam',
 loss='categorical_crossentropy',
 metrics=['accuracy'])
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(model,to_file="model.png",show_shapes=True,show_layer_names=True,rankdir="TB",expand_nested=False,dpi=96, )
from IPython.display import Image
Image('model.png')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
 loss='categorical_crossentropy',
 metrics=['accuracy'])
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(model,to_file="model.png",show_shapes=True,show_layer_names=True,rankdir="TB",expand_nested=False,dpi=96, )
from IPython.display import Image
Image('model.png')

# %%
from tensorflow.keras.utils import plot_model
tf.keras.utils.plot_model(model,to_file="model.png",show_shapes=True,show_layer_names=True,rankdir="TB",expand_nested=False,dpi=96, )
from IPython.display import Image
Image('model.png')

# %%
history = model.fit(x_train, y_train,
 batch_size=128,
 epochs=20,
 validation_split=0.2,
 verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-c561b133f49a> in <cell line: 1>()
# ----> 1 history = model.fit(x_train, y_train,
#       2  batch_size=128,
#       3  epochs=20,
#       4  validation_split=0.2,
#       5  verbose=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/data_adapter_utils.py in check_data_cardinality(data)
#     112             )
#     113             msg += f"'{label}' sizes: {sizes}\n"
# --> 114         raise ValueError(msg)
#     115
#     116
#
# ValueError: Data cardinality is ambiguous. Make sure all arrays contain the same number of samples.'x' sizes: 120000
# 'y' sizes: 50000

# %%
x_train.shape
# Out:
# (150000, 1024)
