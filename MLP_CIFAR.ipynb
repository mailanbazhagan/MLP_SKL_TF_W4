# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
def load_and_preprocess_data():
    # Load MNIST dataset
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Normalize pixel values
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # Reshape images to 1D arrays
    x_train = x_train.reshape(-1, 32*32*3)
    x_test = x_test.reshape(-1, 32*32*3)

    # One-hot encode labels
    y_train = tf.keras.utils.to_categorical(y_train, 10)
    y_test = tf.keras.utils.to_categorical(y_test, 10)
    
    return (x_train, y_train), (x_test, y_test)

# %%
def create_model():
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(3072,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])
    
    return model

# %%
def train(model, x_train, y_train, x_test, y_test):
    # Train the model
    history = model.fit(x_train, y_train,
    batch_size=128,
    epochs=50,
    validation_split=0.2,
    verbose=1)

    return history

# %%
def plot_training_history(history, test_loss, test_accuracy):
    # Extract data from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Plot training and validation accuracy
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.axhline(y=test_accuracy, color='g', linestyle='--', label='Test Accuracy')
    plt.title('Training, Validation, and Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.axhline(y=test_loss, color='g', linestyle='--', label='Test Loss')
    plt.title('Training, Validation, and Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

def plot_confusion_matrix(model, x_test, y_test):
    # Get predictions for the test set
    y_pred = model.predict(x_test)
    y_pred_classes = np.argmax(y_pred, axis=1)  # Convert predictions to class indices
    y_true = np.argmax(y_test, axis=1)          # Convert one-hot labels to class indices

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred_classes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))

    # Plot the confusion matrix
    plt.figure(figsize=(8, 8))
    disp.plot(cmap=plt.cm.Blues, ax=plt.gca())
    plt.title("Confusion Matrix")
    plt.show()

# %%
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()
model = create_model()
history = train(model, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/50
# c:\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.1934 - loss: 2.1764 - val_accuracy: 0.3360 - val_loss: 1.8677
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.3146 - loss: 1.8817 - val_accuracy: 0.3568 - val_loss: 1.7890
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.3316 - loss: 1.8425 - val_accuracy: 0.3809 - val_loss: 1.7390
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.3468 - loss: 1.8006 - val_accuracy: 0.3971 - val_loss: 1.6948
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.3614 - loss: 1.7548 - val_accuracy: 0.4004 - val_loss: 1.6902
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.3782 - loss: 1.7174 - val_accuracy: 0.4063 - val_loss: 1.6708
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3888 - loss: 1.6966 - val_accuracy: 0.4099 - val_loss: 1.6664
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.3910 - loss: 1.6854 - val_accuracy: 0.4163 - val_loss: 1.6419
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.3926 - loss: 1.6872 - val_accuracy: 0.4202 - val_loss: 1.6182
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.3980 - loss: 1.6740 - val_accuracy: 0.4165 - val_loss: 1.6128
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.4039 - loss: 1.6408 - val_accuracy: 0.4290 - val_loss: 1.6210
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.4088 - loss: 1.6361 - val_accuracy: 0.4282 - val_loss: 1.6174
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4142 - loss: 1.6273 - val_accuracy: 0.4298 - val_loss: 1.5887
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4219 - loss: 1.6153 - val_accuracy: 0.4438 - val_loss: 1.5568
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4200 - loss: 1.6106 - val_accuracy: 0.4393 - val_loss: 1.5977
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4253 - loss: 1.6057 - val_accuracy: 0.4444 - val_loss: 1.5783
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4262 - loss: 1.5951 - val_accuracy: 0.4507 - val_loss: 1.5490
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4291 - loss: 1.5812 - val_accuracy: 0.4376 - val_loss: 1.5777
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4339 - loss: 1.5728 - val_accuracy: 0.4612 - val_loss: 1.5576
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4361 - loss: 1.5634 - val_accuracy: 0.4502 - val_loss: 1.5564
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4418 - loss: 1.5559 - val_accuracy: 0.4566 - val_loss: 1.5243
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.4397 - loss: 1.5499 - val_accuracy: 0.4438 - val_loss: 1.5700
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.4374 - loss: 1.5597 - val_accuracy: 0.4535 - val_loss: 1.5437
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.4276 - loss: 1.5811 - val_accuracy: 0.4458 - val_loss: 1.5602
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.4486 - loss: 1.5430 - val_accuracy: 0.4633 - val_loss: 1.5256
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4444 - loss: 1.5474 - val_accuracy: 0.4614 - val_loss: 1.5293
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4497 - loss: 1.5307 - val_accuracy: 0.4665 - val_loss: 1.5179
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4468 - loss: 1.5373 - val_accuracy: 0.4636 - val_loss: 1.5201
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4487 - loss: 1.5290 - val_accuracy: 0.4534 - val_loss: 1.5515
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4531 - loss: 1.5269 - val_accuracy: 0.4553 - val_loss: 1.5221
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4514 - loss: 1.5198 - val_accuracy: 0.4457 - val_loss: 1.5663
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4514 - loss: 1.5249 - val_accuracy: 0.4638 - val_loss: 1.5005
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4530 - loss: 1.5102 - val_accuracy: 0.4589 - val_loss: 1.5143
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4597 - loss: 1.5049 - val_accuracy: 0.4680 - val_loss: 1.4931
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4620 - loss: 1.5071 - val_accuracy: 0.4738 - val_loss: 1.4961
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4624 - loss: 1.4895 - val_accuracy: 0.4522 - val_loss: 1.5364
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4602 - loss: 1.5049 - val_accuracy: 0.4686 - val_loss: 1.5004
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4618 - loss: 1.4985 - val_accuracy: 0.4627 - val_loss: 1.5085
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4609 - loss: 1.4933 - val_accuracy: 0.4682 - val_loss: 1.5147
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4637 - loss: 1.4971 - val_accuracy: 0.4585 - val_loss: 1.5157
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4671 - loss: 1.4846 - val_accuracy: 0.4675 - val_loss: 1.4992
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4698 - loss: 1.4787 - val_accuracy: 0.4742 - val_loss: 1.4895
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4686 - loss: 1.4941 - val_accuracy: 0.4519 - val_loss: 1.5275
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4657 - loss: 1.4886 - val_accuracy: 0.4719 - val_loss: 1.4959
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4685 - loss: 1.4838 - val_accuracy: 0.4655 - val_loss: 1.5070
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4697 - loss: 1.4733 - val_accuracy: 0.4729 - val_loss: 1.4736
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4761 - loss: 1.4619 - val_accuracy: 0.4693 - val_loss: 1.4837
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.4720 - loss: 1.4678 - val_accuracy: 0.4713 - val_loss: 1.4920
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.4683 - loss: 1.4760 - val_accuracy: 0.4739 - val_loss: 1.4812
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4734 - loss: 1.4627 - val_accuracy: 0.4662 - val_loss: 1.4817

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,216,672 (19.90 MB)
#  Trainable params: 1,738,890 (6.63 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,477,782 (13.27 MB)

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
plot_training_history(history, test_loss, test_accuracy)
plot_confusion_matrix(model, x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
