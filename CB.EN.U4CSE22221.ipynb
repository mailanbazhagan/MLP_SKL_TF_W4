# %% [markdown]
# # Question-1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
def loadData():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
    return (x_train, y_train), (x_test, y_test)

# %%
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# %%
def train(model, x_train, y_train, x_test, y_test):
    history = model.fit(x_train, y_train,
                        batch_size=128,
                        epochs=20,
                        validation_split=0.2,
                        verbose=1)

# %%
(x_train, y_train), (x_test, y_test) = load_and_preprocess_data()
model = create_model()
train(model, x_train, y_train, x_test, y_test)
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)
# Out:
# Epoch 1/20
# C:\Users\sbhar\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8066 - loss: 0.6192 - val_accuracy: 0.9612 - val_loss: 0.1262
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9575 - loss: 0.1386 - val_accuracy: 0.9698 - val_loss: 0.1011
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9707 - loss: 0.0945 - val_accuracy: 0.9727 - val_loss: 0.0910
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9784 - loss: 0.0692 - val_accuracy: 0.9731 - val_loss: 0.0860
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9820 - loss: 0.0568 - val_accuracy: 0.9767 - val_loss: 0.0865
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9835 - loss: 0.0504 - val_accuracy: 0.9759 - val_loss: 0.0840
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9863 - loss: 0.0426 - val_accuracy: 0.9737 - val_loss: 0.0935
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9881 - loss: 0.0386 - val_accuracy: 0.9787 - val_loss: 0.0778
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9872 - loss: 0.0395 - val_accuracy: 0.9798 - val_loss: 0.0884
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9889 - loss: 0.0356 - val_accuracy: 0.9812 - val_loss: 0.0767
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9914 - loss: 0.0291 - val_accuracy: 0.9784 - val_loss: 0.0955
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9904 - loss: 0.0291 - val_accuracy: 0.9793 - val_loss: 0.0892
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9911 - loss: 0.0278 - val_accuracy: 0.9799 - val_loss: 0.0845
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9928 - loss: 0.0222 - val_accuracy: 0.9791 - val_loss: 0.0865
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9939 - loss: 0.0186 - val_accuracy: 0.9803 - val_loss: 0.0942
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9926 - loss: 0.0214 - val_accuracy: 0.9797 - val_loss: 0.0857
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9941 - loss: 0.0177 - val_accuracy: 0.9783 - val_loss: 0.0987
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9942 - loss: 0.0162 - val_accuracy: 0.9810 - val_loss: 0.0918
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9943 - loss: 0.0175 - val_accuracy: 0.9795 - val_loss: 0.1048
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9937 - loss: 0.0196 - val_accuracy: 0.9816 - val_loss: 0.0937

# %% [markdown]
# # Question-2

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
def loadData():
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
    return (x_train, y_train), (x_test, y_test)

# %%
def preprocessCifar(x_train, y_train, x_test, y_test):
    x_train = x_train.reshape(-1, 32*32*3)
    x_test = x_test.reshape(-1, 32*32*3)
    
    y_train = tf.keras.utils.to_categorical(y_train, 10)
    y_test = tf.keras.utils.to_categorical(y_test, 10)
    
    return (x_train, y_train), (x_test, y_test)

# %%
def create_model(modelSize):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(512, activation='relu', input_shape=(modelSize,)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam',
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    
    return model

# %%
(x_train, y_train), (x_test, y_test) = loadData()
(x_train, y_train), (x_test, y_test) = preprocessCifar(x_train, y_train, x_test, y_test)

# %%
cifarModel = create_model(3072)
train(cifarModel, x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.1037 - loss: 62.1841 - val_accuracy: 0.0959 - val_loss: 2.3038
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.0968 - loss: 2.3033 - val_accuracy: 0.0956 - val_loss: 2.3037
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1032 - loss: 2.3026 - val_accuracy: 0.0958 - val_loss: 2.3034
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1035 - loss: 2.3023 - val_accuracy: 0.0960 - val_loss: 2.3027
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.1030 - loss: 2.3020 - val_accuracy: 0.0955 - val_loss: 2.3032
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1029 - loss: 2.3026 - val_accuracy: 0.0953 - val_loss: 2.3031
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.0990 - loss: 2.3025 - val_accuracy: 0.0977 - val_loss: 2.3031
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1021 - loss: 2.3024 - val_accuracy: 0.0957 - val_loss: 2.3029
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0994 - loss: 2.3028 - val_accuracy: 0.0979 - val_loss: 2.3029
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1018 - loss: 2.3018 - val_accuracy: 0.0976 - val_loss: 2.3035
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.0995 - loss: 2.3025 - val_accuracy: 0.0952 - val_loss: 2.3034
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0991 - loss: 2.3029 - val_accuracy: 0.0952 - val_loss: 2.3034
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1023 - loss: 2.3026 - val_accuracy: 0.0977 - val_loss: 2.3032
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0979 - loss: 2.3024 - val_accuracy: 0.0977 - val_loss: 2.3033
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.1008 - loss: 2.3025 - val_accuracy: 0.0952 - val_loss: 2.3032
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.0984 - loss: 2.3027 - val_accuracy: 0.0952 - val_loss: 2.3033
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.1011 - loss: 2.3026 - val_accuracy: 0.0952 - val_loss: 2.3033
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0959 - loss: 2.3030 - val_accuracy: 0.0952 - val_loss: 2.3032
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1013 - val_loss: 2.3031
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.0954 - loss: 2.3027 - val_accuracy: 0.0952 - val_loss: 2.3032

# %%
    tf.keras.utils.plot_model(
         model,
         to_file="cifarModel.png",
         show_shapes=True,
         show_layer_names=True,
         rankdir="TB",
         expand_nested=False,
         dpi=96,
    )
    from IPython.display import Image
    Image('cifarModel.png')
